# %%
from ibm_watsonx_ai.foundation_models import ModelInference
from ibm_watsonx_ai import Credentials

# Step 1: Set credentials
creds = Credentials(
    url="https://us-south.ml.cloud.ibm.com",
    api_key="qROQ6mqT8YcgFTwjCjE0TG4TJE4wjqrfa-CMasBywnty"
)

# Step 2: Initialize model
model = ModelInference(
    model_id="ibm/granite-3-3-8b-instruct",  # ✅ Working model
    credentials=creds,
    project_id="8918bbc0-c6f9-4524-947e-e0280206b4d9"
)

# ✅ Step 3: Use generate() correctly
response = model.generate(
    prompt="What is UPI and how can people use it safely?",
    params={
        "temperature": 0.7,
        "max_tokens": 300
    }
)

# ✅ Step 4: Show result
print(response['results'][0]['generated_text'])
# Out:
# UPI (Unified Payments Interface) is a real-time payment system developed by the

# %%
response = model.generate(
    prompt="What is the difference between credit card and debit card?",
    params={"temperature": 0.7, "max_tokens": 300}
)
print(response['results'][0]['generated_text'])
# Out:
# Credit card and debit card are both payment cards, but they work differently. A credit
